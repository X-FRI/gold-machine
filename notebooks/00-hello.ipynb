// %% [markdown]
// # Gold Machine - Environment Check
//
// 验证 F# + Python(akshare) + Plotly.NET 全部就绪

// %%
printfn $"F#: {typeof<int>.Assembly.GetName().Version}"

// %%
#r "nuget: Plotly.NET, 5.0.0"
#r "nuget: Plotly.NET.Interactive, 5.0.0"
open Plotly.NET
Chart.Line([1.,2.,3.], [1.,4.,9.]) |> Chart.withTitle "Plotly.NET works"
